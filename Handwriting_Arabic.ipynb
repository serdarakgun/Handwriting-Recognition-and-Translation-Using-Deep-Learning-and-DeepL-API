# %% [markdown]
# <a href="https://colab.research.google.com/github/serdarakgun/Handwriting-Recognition-and-Translation-Using-Deep-Learning-and-DeepL-API/blob/main/Handwriting_Arabic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub matplotlib seaborn tensorflow keras pandas scikit-learn -q
import os, warnings
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import tensorflow as tf
import pandas as pd
import keras
import kagglehub
import random
from keras.models import Model
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, Input, RandomContrast, RandomFlip,  RandomRotation, RandomTranslation
from tensorflow.keras.utils import to_categorical, plot_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from PIL import Image
import warnings
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
# Download latest version
path = kagglehub.dataset_download("mloey1/ahcd1")

print("Path to dataset files:", path)



# Dataset içindeki dosyaları listele
for root, dirs, files in os.walk(path):
    print("Dataset içindeki dosyalar:", files)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.5)
# Path to dataset files: /root/.cache/kagglehub/datasets/mloey1/ahcd1/versions/2
# Dataset içindeki dosyalar: ['csvTrainLabel 13440x1.csv', 'csvTestImages 3360x1024.csv', 'csvTestLabel 3360x1.csv', 'Train+Test Images Matlab.mat', 'csvTrainImages 13440x1024.csv']
# Dataset içindeki dosyalar: []
# Dataset içindeki dosyalar: ['id_7100_label_20.png', 'id_1176_label_7.png', 'id_5201_label_7.png', 'id_8401_label_15.png', 'id_3252_label_15.png', 'id_8706_label_25.png', 'id_8276_label_27.png', 'id_4398_label_18.png', 'id_460_label_2.png', 'id_5606_label_1.png', 'id_11216_label_2.png', 'id_10823_label_9.png', 'id_10073_label_28.png', 'id_909_label_2.png', 'id_2691_label_1.png', 'id_7534_label_18.png', 'id_9139_label_23.png', 'id_12960_label_24.png', 'id_9515_label_14.png', 'id_5453_label_10.png', 'id_2516_label_7.png', 'id_1691_label_16.png', 'id_4507_label_4.png', 'id_13292_label_10.png', 'id_2169_label_20.png', 'id_7746_label_17.png', 'id_8876_label_18.png', 'id_1832_label_5.png', 'id_4453_label_25.png', 'id_5029_label_13.png', 'id_3852_label_6.png', 'id_4962_label_5.png', 'id_8596_label_11.png', 'id_453_label_1.png', 'id_9187_label_1.png', 'id_11007_label_4.png', 'id_1195_label_10.png', 'id_7977_label_18.png', 'id_10945_label_25.png', 'id_6812_label_12.png', 'id_4772_label_9.png', 'id_6198_label_19.png', 'id_6074_label_4.png', 'id_13345_label_17.png', 'id_7934_label_12.png', 'id_10274_label_25.png', 'id_12763_label_28.png', 'id_4165_label_17.png', 'id_12061_label_24.png', 'id_10611_label_11.png', 'id_458_label_2.png', 'id_9314_label_17.png', 'id_11273_label_10.png', 'id_3650_label_9.png', 'id_12086_label_27.png', 'id_11108_label_17.png', 'id_11727_label_10.png', 'id_9009_label_7.png', 'id_585_label_18.png', 'id_7904_label_8.png', 'id_8194_label_17.png', 'id_13036_label_6.png', 'id_3795_label_27.png', 'id_2179_label_21.png', 'id_1913_label_16.png', 'id_8490_label_26.png', 'id_8732_label_28.png', 'id_7225_label_8.png', 'id_3389_label_4.png', 'id_3594_label_2.png', 'id_6278_label_1.png', 'id_9429_label_3.png', 'id_3618_label_5.png', 'id_3878_label_9.png', 'id_12563_label_3.png', 'id_6190_label_18.png', 'id_4025_label_28.png', 'id_8303_label_2.png', 'id_3928_label_15.png', 'id_1387_label_6.png', 'id_1973_label_23.png', 'id_12753_label_27.png', 'id_3487_label_16.png', 'id_6745_label_4.png', 'id_6076_label_4.png', 'id_13107_label_15.png', 'id_5813_label_27.png', 'id_7163_label_28.png', 'id_11789_label_18.png', 'id_10006_label_19.png', 'id_1275_label_20.png', 'id_4806_label_13.png', 'id_4872_label_21.png', 'id_1796_label_1.png', 'id_7895_label_7.png', 'id_8355_label_9.png', 'id_6908_label_24.png', 'id_12351_label_4.png', 'id_11276_label_10.png', 'id_8016_label_22.png', 'id_3493_label_17.png', 'id_13040_label_6.png', 'id_7657_label_6.png', 'id_267_label_6.png', 'id_1849_label_8.png', 'id_12075_label_26.png', 'id_5450_label_10.png', 'id_9881_label_4.png', 'id_8752_label_2.png', 'id_1014_label_15.png', 'id_11504_label_10.png', 'id_306_label_11.png', 'id_2804_label_15.png', 'id_433_label_27.png', 'id_2950_label_5.png', 'id_3080_label_21.png', 'id_1859_label_9.png', 'id_1555_label_27.png', 'id_10335_label_4.png', 'id_873_label_26.png', 'id_8984_label_3.png', 'id_1230_label_14.png', 'id_6102_label_7.png', 'id_13401_label_24.png', 'id_13150_label_20.png', 'id_4622_label_18.png', 'id_8789_label_7.png', 'id_6743_label_3.png', 'id_13396_label_23.png', 'id_944_label_6.png', 'id_10005_label_19.png', 'id_3421_label_8.png', 'id_8814_label_10.png', 'id_6530_label_5.png', 'id_6954_label_2.png', 'id_11575_label_19.png', 'id_6596_label_13.png', 'id_11910_label_5.png', 'id_4077_label_6.png', 'id_836_label_21.png', 'id_13008_label_2.png', 'id_9587_label_23.png', 'id_5667_label_9.png', 'id_3338_label_26.png', 'id_10472_label_21.png', 'id_6783_label_8.png', 'id_7755_label_18.png', 'id_2638_label_22.png', 'id_1228_label_14.png', 'id_12892_label_16.png', 'id_189_label_24.png', 'id_2333_label_12.png', 'id_8801_label_9.png', 'id_7462_label_9.png', 'id_8821_label_11.png', 'id_7669_label_7.png', 'id_1029_label_17.png', 'id_11018_label_6.png', 'id_11148_label_22.png', 'id_11534_label_14.png', 'id_8831_label_12.png', 'id_8773_label_5.png', 'id_4888_label_23.png', 'id_7497_label_14.png', 'id_1351_label_1.png', 'id_7025_label_11.png', 'id_7417_label_4.png', 'id_ ...
# Dataset içindeki dosyalar: []
# Dataset içindeki dosyalar: ['id_2646_label_7.png', 'id_3052_label_14.png', 'id_2509_label_23.png', 'id_3125_label_23.png', 'id_1440_label_20.png', 'id_2717_label_15.png', 'id_1195_label_10.png', 'id_2383_label_16.png', 'id_20_label_10.png', 'id_1877_label_15.png', 'id_1393_label_25.png', 'id_3141_label_3.png', 'id_55_label_28.png', 'id_3257_label_5.png', 'id_2410_label_1.png', 'id_585_label_13.png', 'id_2478_label_7.png', 'id_453_label_3.png', 'id_576_label_8.png', 'id_2978_label_5.png', 'id_2212_label_14.png', 'id_1609_label_21.png', 'id_2791_label_24.png', 'id_478_label_15.png', 'id_2369_label_9.png', 'id_2776_label_16.png', 'id_3177_label_21.png', 'id_1807_label_8.png', 'id_412_label_10.png', 'id_2502_label_19.png', 'id_104_label_24.png', 'id_341_label_3.png', 'id_2482_label_9.png', 'id_1050_label_21.png', 'id_3151_label_8.png', 'id_348_label_6.png', 'id_1241_label_5.png', 'id_3042_label_9.png', 'id_1360_label_8.png', 'id_2525_label_3.png', 'id_1240_label_4.png', 'id_856_label_8.png', 'id_2463_label_28.png', 'id_594_label_17.png', 'id_2299_label_2.png', 'id_1921_label_9.png', 'id_210_label_21.png', 'id_690_label_9.png', 'id_1323_label_18.png', 'id_1906_label_1.png', 'id_1265_label_17.png', 'id_1886_label_19.png', 'id_635_label_10.png', 'id_1759_label_12.png', 'id_1752_label_8.png', 'id_1211_label_18.png', 'id_3115_label_18.png', 'id_2214_label_15.png', 'id_1308_label_10.png', 'id_2052_label_18.png', 'id_2304_label_4.png', 'id_438_label_23.png', 'id_156_label_22.png', 'id_3061_label_19.png', 'id_616_label_28.png', 'id_2323_label_14.png', 'id_1991_label_16.png', 'id_2206_label_11.png', 'id_1536_label_12.png', 'id_3046_label_11.png', 'id_143_label_16.png', 'id_2063_label_24.png', 'id_2536_label_8.png', 'id_777_label_25.png', 'id_278_label_27.png', 'id_1399_label_28.png', 'id_2649_label_9.png', 'id_1637_label_7.png', 'id_2151_label_12.png', 'id_421_label_15.png', 'id_3224_label_16.png', 'id_3274_label_13.png', 'id_1402_label_1.png', 'id_39_label_20.png', 'id_3356_label_26.png', 'id_2361_label_5.png', 'id_643_label_14.png', 'id_652_label_18.png', 'id_2317_label_11.png', 'id_2711_label_12.png', 'id_2642_label_5.png', 'id_911_label_8.png', 'id_265_label_21.png', 'id_2036_label_10.png', 'id_492_label_22.png', 'id_1517_label_3.png', 'id_2382_label_15.png', 'id_1557_label_23.png', 'id_2595_label_10.png', 'id_2476_label_6.png', 'id_506_label_1.png', 'id_2051_label_18.png', 'id_1027_label_10.png', 'id_1183_label_4.png', 'id_3337_label_17.png', 'id_1931_label_14.png', 'id_396_label_2.png', 'id_2486_label_11.png', 'id_601_label_21.png', 'id_1054_label_23.png', 'id_3131_label_26.png', 'id_3312_label_4.png', 'id_1088_label_12.png', 'id_2487_label_12.png', 'id_2092_label_10.png', 'id_587_label_14.png', 'id_1545_label_17.png', 'id_401_label_5.png', 'id_1904_label_28.png', 'id_3074_label_25.png', 'id_606_label_23.png', 'id_1787_label_26.png', 'id_755_label_14.png', 'id_2977_label_5.png', 'id_2691_label_2.png', 'id_1718_label_19.png', 'id_3180_label_22.png', 'id_2719_label_16.png', 'id_2574_label_27.png', 'id_2454_label_23.png', 'id_2424_label_8.png', 'id_1018_label_5.png', 'id_1710_label_15.png', 'id_2397_label_23.png', 'id_131_label_10.png', 'id_1391_label_24.png', 'id_369_label_17.png', 'id_45_label_23.png', 'id_645_label_15.png', 'id_3345_label_21.png', 'id_2755_label_6.png', 'id_526_label_11.png', 'id_2531_label_6.png', 'id_26_label_13.png', 'id_204_label_18.png', 'id_1505_label_25.png', 'id_2375_label_12.png', 'id_3161_label_13.png', 'id_1161_label_21.png', 'id_3014_label_23.png', 'id_3124_label_22.png', 'id_783_label_28.png', 'id_1890_label_21.png', 'id_347_label_6.png', 'id_1708_label_14.png', 'id_1354_label_5.png', 'id_1444_label_22.png', 'id_2083_label_6.png', 'id_573_label_7.png', 'id_116_label_2.png', 'id_829_label_23.png', 'id_2225_label_21.png', 'id_1897_label_25.png', 'id_1809_label_9.png', 'id_984_label_16.png', 'id_1382_label_19.png', 'id_2503_label_20.png', 'id_1249_label_9.png', 'id_2607_label_16.png', 'id_1789_label_27.png' ...
# Dataset içindeki dosyalar: []
# Dataset içindeki dosyalar: ['id_2646_label_7.png', 'id_3052_label_14.png', 'id_2509_label_23.png', 'id_3125_label_23.png', 'id_1440_label_20.png', 'id_2717_label_15.png', 'id_1195_label_10.png', 'id_2383_label_16.png', 'id_20_label_10.png', 'id_1877_label_15.png', 'id_1393_label_25.png', 'id_3141_label_3.png', 'id_55_label_28.png', 'id_3257_label_5.png', 'id_2410_label_1.png', 'id_585_label_13.png', 'id_2478_label_7.png', 'id_453_label_3.png', 'id_576_label_8.png', 'id_2978_label_5.png', 'id_2212_label_14.png', 'id_1609_label_21.png', 'id_2791_label_24.png', 'id_478_label_15.png', 'id_2369_label_9.png', 'id_2776_label_16.png', 'id_3177_label_21.png', 'id_1807_label_8.png', 'id_412_label_10.png', 'id_2502_label_19.png', 'id_104_label_24.png', 'id_341_label_3.png', 'id_2482_label_9.png', 'id_1050_label_21.png', 'id_3151_label_8.png', 'id_348_label_6.png', 'id_1241_label_5.png', 'id_3042_label_9.png', 'id_1360_label_8.png', 'id_2525_label_3.png', 'id_1240_label_4.png', 'id_856_label_8.png', 'id_2463_label_28.png', 'id_594_label_17.png', 'id_2299_label_2.png', 'id_1921_label_9.png', 'id_210_label_21.png', 'id_690_label_9.png', 'id_1323_label_18.png', 'id_1906_label_1.png', 'id_1265_label_17.png', 'id_1886_label_19.png', 'id_635_label_10.png', 'id_1759_label_12.png', 'id_1752_label_8.png', 'id_1211_label_18.png', 'id_3115_label_18.png', 'id_2214_label_15.png', 'id_1308_label_10.png', 'id_2052_label_18.png', 'id_2304_label_4.png', 'id_438_label_23.png', 'id_156_label_22.png', 'id_3061_label_19.png', 'id_616_label_28.png', 'id_2323_label_14.png', 'id_1991_label_16.png', 'id_2206_label_11.png', 'id_1536_label_12.png', 'id_3046_label_11.png', 'id_143_label_16.png', 'id_2063_label_24.png', 'id_2536_label_8.png', 'id_777_label_25.png', 'id_278_label_27.png', 'id_1399_label_28.png', 'id_2649_label_9.png', 'id_1637_label_7.png', 'id_2151_label_12.png', 'id_421_label_15.png', 'id_3224_label_16.png', 'id_3274_label_13.png', 'id_1402_label_1.png', 'id_39_label_20.png', 'id_3356_label_26.png', 'id_2361_label_5.png', 'id_643_label_14.png', 'id_652_label_18.png', 'id_2317_label_11.png', 'id_2711_label_12.png', 'id_2642_label_5.png', 'id_911_label_8.png', 'id_265_label_21.png', 'id_2036_label_10.png', 'id_492_label_22.png', 'id_1517_label_3.png', 'id_2382_label_15.png', 'id_1557_label_23.png', 'id_2595_label_10.png', 'id_2476_label_6.png', 'id_506_label_1.png', 'id_2051_label_18.png', 'id_1027_label_10.png', 'id_1183_label_4.png', 'id_3337_label_17.png', 'id_1931_label_14.png', 'id_396_label_2.png', 'id_2486_label_11.png', 'id_601_label_21.png', 'id_1054_label_23.png', 'id_3131_label_26.png', 'id_3312_label_4.png', 'id_1088_label_12.png', 'id_2487_label_12.png', 'id_2092_label_10.png', 'id_587_label_14.png', 'id_1545_label_17.png', 'id_401_label_5.png', 'id_1904_label_28.png', 'id_3074_label_25.png', 'id_606_label_23.png', 'id_1787_label_26.png', 'id_755_label_14.png', 'id_2977_label_5.png', 'id_2691_label_2.png', 'id_1718_label_19.png', 'id_3180_label_22.png', 'id_2719_label_16.png', 'id_2574_label_27.png', 'id_2454_label_23.png', 'id_2424_label_8.png', 'id_1018_label_5.png', 'id_1710_label_15.png', 'id_2397_label_23.png', 'id_131_label_10.png', 'id_1391_label_24.png', 'id_369_label_17.png', 'id_45_label_23.png', 'id_645_label_15.png', 'id_3345_label_21.png', 'id_2755_label_6.png', 'id_526_label_11.png', 'id_2531_label_6.png', 'id_26_label_13.png', 'id_204_label_18.png', 'id_1505_label_25.png', 'id_2375_label_12.png', 'id_3161_label_13.png', 'id_1161_label_21.png', 'id_3014_label_23.png', 'id_3124_label_22.png', 'id_783_label_28.png', 'id_1890_label_21.png', 'id_347_label_6.png', 'id_1708_label_14.png', 'id_1354_label_5.png', 'id_1444_label_22.png', 'id_2083_label_6.png', 'id_573_label_7.png', 'id_116_label_2.png', 'id_829_label_23.png', 'id_2225_label_21.png', 'id_1897_label_25.png', 'id_1809_label_9.png', 'id_984_label_16.png', 'id_1382_label_19.png', 'id_2503_label_20.png', 'id_1249_label_9.png', 'id_2607_label_16.png', 'id_1789_label_27.png' ...
# Dataset içindeki dosyalar: ['csvTrainLabel 13440x1.csv', 'csvTestImages 3360x1024.csv', 'csvTestLabel 3360x1.csv', 'csvTrainImages 13440x1024.csv']
# Dataset içindeki dosyalar: ['csvTrainLabel 13440x1.csv', 'csvTestImages 3360x1024.csv', 'csvTestLabel 3360x1.csv', 'csvTrainImages 13440x1024.csv']
# Dataset içindeki dosyalar: []
# Dataset içindeki dosyalar: ['id_7100_label_20.png', 'id_1176_label_7.png', 'id_5201_label_7.png', 'id_8401_label_15.png', 'id_3252_label_15.png', 'id_8706_label_25.png', 'id_8276_label_27.png', 'id_4398_label_18.png', 'id_460_label_2.png', 'id_5606_label_1.png', 'id_11216_label_2.png', 'id_10823_label_9.png', 'id_10073_label_28.png', 'id_909_label_2.png', 'id_2691_label_1.png', 'id_7534_label_18.png', 'id_9139_label_23.png', 'id_12960_label_24.png', 'id_9515_label_14.png', 'id_5453_label_10.png', 'id_2516_label_7.png', 'id_1691_label_16.png', 'id_4507_label_4.png', 'id_13292_label_10.png', 'id_2169_label_20.png', 'id_7746_label_17.png', 'id_8876_label_18.png', 'id_1832_label_5.png', 'id_4453_label_25.png', 'id_5029_label_13.png', 'id_3852_label_6.png', 'id_4962_label_5.png', 'id_8596_label_11.png', 'id_453_label_1.png', 'id_9187_label_1.png', 'id_11007_label_4.png', 'id_1195_label_10.png', 'id_7977_label_18.png', 'id_10945_label_25.png', 'id_6812_label_12.png', 'id_4772_label_9.png', 'id_6198_label_19.png', 'id_6074_label_4.png', 'id_13345_label_17.png', 'id_7934_label_12.png', 'id_10274_label_25.png', 'id_12763_label_28.png', 'id_4165_label_17.png', 'id_12061_label_24.png', 'id_10611_label_11.png', 'id_458_label_2.png', 'id_9314_label_17.png', 'id_11273_label_10.png', 'id_3650_label_9.png', 'id_12086_label_27.png', 'id_11108_label_17.png', 'id_11727_label_10.png', 'id_9009_label_7.png', 'id_585_label_18.png', 'id_7904_label_8.png', 'id_8194_label_17.png', 'id_13036_label_6.png', 'id_3795_label_27.png', 'id_2179_label_21.png', 'id_1913_label_16.png', 'id_8490_label_26.png', 'id_8732_label_28.png', 'id_7225_label_8.png', 'id_3389_label_4.png', 'id_3594_label_2.png', 'id_6278_label_1.png', 'id_9429_label_3.png', 'id_3618_label_5.png', 'id_3878_label_9.png', 'id_12563_label_3.png', 'id_6190_label_18.png', 'id_4025_label_28.png', 'id_8303_label_2.png', 'id_3928_label_15.png', 'id_1387_label_6.png', 'id_1973_label_23.png', 'id_12753_label_27.png', 'id_3487_label_16.png', 'id_6745_label_4.png', 'id_6076_label_4.png', 'id_13107_label_15.png', 'id_5813_label_27.png', 'id_7163_label_28.png', 'id_11789_label_18.png', 'id_10006_label_19.png', 'id_1275_label_20.png', 'id_4806_label_13.png', 'id_4872_label_21.png', 'id_1796_label_1.png', 'id_7895_label_7.png', 'id_8355_label_9.png', 'id_6908_label_24.png', 'id_12351_label_4.png', 'id_11276_label_10.png', 'id_8016_label_22.png', 'id_3493_label_17.png', 'id_13040_label_6.png', 'id_7657_label_6.png', 'id_267_label_6.png', 'id_1849_label_8.png', 'id_12075_label_26.png', 'id_5450_label_10.png', 'id_9881_label_4.png', 'id_8752_label_2.png', 'id_1014_label_15.png', 'id_11504_label_10.png', 'id_306_label_11.png', 'id_2804_label_15.png', 'id_433_label_27.png', 'id_2950_label_5.png', 'id_3080_label_21.png', 'id_1859_label_9.png', 'id_1555_label_27.png', 'id_10335_label_4.png', 'id_873_label_26.png', 'id_8984_label_3.png', 'id_1230_label_14.png', 'id_6102_label_7.png', 'id_13401_label_24.png', 'id_13150_label_20.png', 'id_4622_label_18.png', 'id_8789_label_7.png', 'id_6743_label_3.png', 'id_13396_label_23.png', 'id_944_label_6.png', 'id_10005_label_19.png', 'id_3421_label_8.png', 'id_8814_label_10.png', 'id_6530_label_5.png', 'id_6954_label_2.png', 'id_11575_label_19.png', 'id_6596_label_13.png', 'id_11910_label_5.png', 'id_4077_label_6.png', 'id_836_label_21.png', 'id_13008_label_2.png', 'id_9587_label_23.png', 'id_5667_label_9.png', 'id_3338_label_26.png', 'id_10472_label_21.png', 'id_6783_label_8.png', 'id_7755_label_18.png', 'id_2638_label_22.png', 'id_1228_label_14.png', 'id_12892_label_16.png', 'id_189_label_24.png', 'id_2333_label_12.png', 'id_8801_label_9.png', 'id_7462_label_9.png', 'id_8821_label_11.png', 'id_7669_label_7.png', 'id_1029_label_17.png', 'id_11018_label_6.png', 'id_11148_label_22.png', 'id_11534_label_14.png', 'id_8831_label_12.png', 'id_8773_label_5.png', 'id_4888_label_23.png', 'id_7497_label_14.png', 'id_1351_label_1.png', 'id_7025_label_11.png', 'id_7417_label_4.png', 'id_ ...

# %%
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed(333)

# %%
# Load Data
data_path = "/root/.cache/kagglehub/datasets/mloey1/ahcd1/versions/2"

# Eğitim ve test veri dosyalarının tam yolunu belirtiyoruz
x_train = pd.read_csv(os.path.join(data_path, "csvTrainImages 13440x1024.csv"), header=None)
y_train = pd.read_csv(os.path.join(data_path, "csvTrainLabel 13440x1.csv"), header=None)
x_test = pd.read_csv(os.path.join(data_path, "csvTestImages 3360x1024.csv"), header=None)
y_test = pd.read_csv(os.path.join(data_path, "csvTestLabel 3360x1.csv"), header=None)

# Verileri kontrol etmek için ilk birkaç satırı görüntüleme (isteğe bağlı)
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
image_data = x_train.iloc[0].values.reshape(32, 32)  # Örneğin, 32x32 boyutunda bir görüntü

# Görüntüyü göster
plt.imshow(image_data, cmap='gray')
plt.show()
x_train.shape[0]
# Out:
# x_train shape: (13440, 1024)
# y_train shape: (13440, 1)
# x_test shape: (3360, 1024)
# y_test shape: (3360, 1)
# 13440

# %%
# Reshape our input data to image shape (32*32)
x_train = x_train.to_numpy().reshape(-1,32,32,1)
x_test = x_test.to_numpy().reshape(-1,32,32,1)

# transform our categorial label to be one hot encoded
y_train = to_categorical(y_train-1)
y_test = to_categorical(y_test-1)

# split train data to craete a validiatation data
(train_inputs, validate_inputs, train_targets, validate_targets) = train_test_split(x_train, y_train, test_size=0.10)

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, AveragePooling2D, Dropout, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
import os

# TensorFlow deterministik olmayan işlemleri devre dışı bırakmak için ayar
os.environ["TF_DETERMINISTIC_OPS"] = "1"

def get_fixed_model():
    In = Input(shape=(32, 32, 1))

    # First block
    x = Conv2D(32, (3, 3), padding="same", activation="relu", kernel_regularizer=l2(1e-4))(In)
    x = BatchNormalization()(x)
    x = Conv2D(32, (3, 3), padding="same", activation="relu", kernel_regularizer=l2(1e-4))(x)
    x = AveragePooling2D((2, 2))(x)  # Output: (16, 16, 32)
    x = Dropout(0.3)(x)

    # Second block
    x = Conv2D(64, (3, 3), padding="same", activation="relu", kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Conv2D(64, (3, 3), padding="same", activation="relu", kernel_regularizer=l2(1e-4))(x)
    x = AveragePooling2D((2, 2))(x)  # Output: (8, 8, 64)
    x = Dropout(0.4)(x)

    # Third block
    x = Conv2D(128, (3, 3), padding="same", activation="relu", kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Conv2D(128, (3, 3), padding="same", activation="relu", kernel_regularizer=l2(1e-4))(x)
    x = AveragePooling2D((2, 2))(x)  # Output: (4, 4, 128)
    x = Dropout(0.5)(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation="relu", kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.5)(x)

    # Output layer
    Out = Dense(28, activation="softmax")(x)

    # Model compilation
    model = Model(In, Out)
    model.compile(
        loss="categorical_crossentropy",
        optimizer=Adam(learning_rate=1e-3),
        metrics=["accuracy"]
    )

    return model




model = get_fixed_model()
plot_model(model, show_shapes=True, show_layer_names=True)

# Augmentation for training data only
datagen = ImageDataGenerator(
    brightness_range=(0.5, 1.5),
    rotation_range=25,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

batch_size = 40

train_data = datagen.flow(train_inputs, train_targets, batch_size=batch_size)
validate_data = ImageDataGenerator().flow(validate_inputs, validate_targets, batch_size=batch_size)

# Learning rate scheduler
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)

# Model fitting
history = model.fit(train_data, validation_data=validate_data, epochs=50, callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 28s 60ms/step - accuracy: 0.1079 - loss: 3.0952 - val_accuracy: 0.3981 - val_loss: 1.6692 - learning_rate: 0.0010
# Epoch 2/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 28s 34ms/step - accuracy: 0.4220 - loss: 1.8001 - val_accuracy: 0.6905 - val_loss: 0.9980 - learning_rate: 0.0010
# Epoch 3/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 22s 40ms/step - accuracy: 0.6247 - loss: 1.2427 - val_accuracy: 0.7292 - val_loss: 0.9481 - learning_rate: 0.0010
# Epoch 4/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.7100 - loss: 0.9942 - val_accuracy: 0.8289 - val_loss: 0.5957 - learning_rate: 0.0010
# Epoch 5/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 19s 34ms/step - accuracy: 0.7562 - loss: 0.8873 - val_accuracy: 0.8579 - val_loss: 0.5625 - learning_rate: 0.0010
# Epoch 6/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 22s 40ms/step - accuracy: 0.7736 - loss: 0.8079 - val_accuracy: 0.9115 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 7/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 19s 34ms/step - accuracy: 0.7867 - loss: 0.7719 - val_accuracy: 0.9040 - val_loss: 0.4631 - learning_rate: 0.0010
# Epoch 8/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 23s 42ms/step - accuracy: 0.8085 - loss: 0.7144 - val_accuracy: 0.9263 - val_loss: 0.3855 - learning_rate: 0.0010
# Epoch 9/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 18s 34ms/step - accuracy: 0.8190 - loss: 0.6762 - val_accuracy: 0.9144 - val_loss: 0.4523 - learning_rate: 0.0010
# Epoch 10/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.8330 - loss: 0.6484 - val_accuracy: 0.9315 - val_loss: 0.3640 - learning_rate: 0.0010
# Epoch 11/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.8468 - loss: 0.6190 - val_accuracy: 0.9375 - val_loss: 0.3321 - learning_rate: 0.0010
# Epoch 12/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.8439 - loss: 0.6235 - val_accuracy: 0.9241 - val_loss: 0.3998 - learning_rate: 0.0010
# Epoch 13/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.8520 - loss: 0.6098 - val_accuracy: 0.9249 - val_loss: 0.4118 - learning_rate: 0.0010
# Epoch 14/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.8601 - loss: 0.5844 - val_accuracy: 0.9516 - val_loss: 0.3184 - learning_rate: 0.0010
# Epoch 15/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.8598 - loss: 0.5856 - val_accuracy: 0.9241 - val_loss: 0.4490 - learning_rate: 0.0010
# Epoch 16/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.8726 - loss: 0.5486 - val_accuracy: 0.9182 - val_loss: 0.4160 - learning_rate: 0.0010
# Epoch 17/50
# 302/303 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8745 - loss: 0.5562
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step - accuracy: 0.8745 - loss: 0.5562 - val_accuracy: 0.9487 - val_loss: 0.3395 - learning_rate: 0.0010
# Epoch 18/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 21s 36ms/step - accuracy: 0.8857 - loss: 0.5084 - val_accuracy: 0.9583 - val_loss: 0.2963 - learning_rate: 5.0000e-04
# Epoch 19/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.8929 - loss: 0.4880 - val_accuracy: 0.9591 - val_loss: 0.3166 - learning_rate: 5.0000e-04
# Epoch 20/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - accuracy: 0.8947 - loss: 0.4894 - val_accuracy: 0.9524 - val_loss: 0.3194 - learning_rate: 5.0000e-04
# Epoch 21/50
# 299/303 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9010 - loss: 0.4633
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - accuracy: 0.9010 - loss: 0.4636 - val_accuracy: 0.9546 - val_loss: 0.3118 - learning_rate: 5.0000e-04
# Epoch 22/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - accuracy: 0.9040 - loss: 0.4592 - val_accuracy: 0.9658 - val_loss: 0.2795 - learning_rate: 2.5000e-04
# Epoch 23/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9142 - loss: 0.4280 - val_accuracy: 0.9658 - val_loss: 0.2741 - learning_rate: 2.5000e-04
# Epoch 24/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.9129 - loss: 0.4240 - val_accuracy: 0.9635 - val_loss: 0.2896 - learning_rate: 2.5000e-04
# Epoch 25/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9159 - loss: 0.4173 - val_accuracy: 0.9583 - val_loss: 0.2976 - learning_rate: 2.5000e-04
# Epoch 26/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - accuracy: 0.9196 - loss: 0.4021 - val_accuracy: 0.9658 - val_loss: 0.2719 - learning_rate: 2.5000e-04
# Epoch 27/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9155 - loss: 0.4108 - val_accuracy: 0.9688 - val_loss: 0.2725 - learning_rate: 2.5000e-04
# Epoch 28/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.9171 - loss: 0.4064 - val_accuracy: 0.9643 - val_loss: 0.2790 - learning_rate: 2.5000e-04
# Epoch 29/50
# 302/303 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9185 - loss: 0.3986
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - accuracy: 0.9185 - loss: 0.3986 - val_accuracy: 0.9635 - val_loss: 0.2901 - learning_rate: 2.5000e-04
# Epoch 30/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.9242 - loss: 0.3850 - val_accuracy: 0.9680 - val_loss: 0.2685 - learning_rate: 1.2500e-04
# Epoch 31/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.9232 - loss: 0.3948 - val_accuracy: 0.9673 - val_loss: 0.2660 - learning_rate: 1.2500e-04
# Epoch 32/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 20s 30ms/step - accuracy: 0.9214 - loss: 0.3935 - val_accuracy: 0.9695 - val_loss: 0.2672 - learning_rate: 1.2500e-04
# Epoch 33/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - accuracy: 0.9233 - loss: 0.3768 - val_accuracy: 0.9695 - val_loss: 0.2630 - learning_rate: 1.2500e-04
# Epoch 34/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.9236 - loss: 0.3739 - val_accuracy: 0.9658 - val_loss: 0.2625 - learning_rate: 1.2500e-04
# Epoch 35/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9234 - loss: 0.3781 - val_accuracy: 0.9673 - val_loss: 0.2572 - learning_rate: 1.2500e-04
# Epoch 36/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9210 - loss: 0.3834 - val_accuracy: 0.9702 - val_loss: 0.2584 - learning_rate: 1.2500e-04
# Epoch 37/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - accuracy: 0.9206 - loss: 0.3743 - val_accuracy: 0.9710 - val_loss: 0.2527 - learning_rate: 1.2500e-04
# Epoch 38/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.9214 - loss: 0.3859 - val_accuracy: 0.9702 - val_loss: 0.2473 - learning_rate: 1.2500e-04
# Epoch 39/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 21s 36ms/step - accuracy: 0.9232 - loss: 0.3755 - val_accuracy: 0.9732 - val_loss: 0.2490 - learning_rate: 1.2500e-04
# Epoch 40/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 20s 34ms/step - accuracy: 0.9240 - loss: 0.3726 - val_accuracy: 0.9717 - val_loss: 0.2443 - learning_rate: 1.2500e-04
# Epoch 41/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9282 - loss: 0.3572 - val_accuracy: 0.9710 - val_loss: 0.2456 - learning_rate: 1.2500e-04
# Epoch 42/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 20s 34ms/step - accuracy: 0.9272 - loss: 0.3567 - val_accuracy: 0.9710 - val_loss: 0.2530 - learning_rate: 1.2500e-04
# Epoch 43/50
# 302/303 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9303 - loss: 0.3519
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.9303 - loss: 0.3520 - val_accuracy: 0.9710 - val_loss: 0.2463 - learning_rate: 1.2500e-04
# Epoch 44/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9305 - loss: 0.3594 - val_accuracy: 0.9717 - val_loss: 0.2471 - learning_rate: 6.2500e-05
# Epoch 45/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step - accuracy: 0.9269 - loss: 0.3551 - val_accuracy: 0.9732 - val_loss: 0.2458 - learning_rate: 6.2500e-05
# Epoch 46/50
# 298/303 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9317 - loss: 0.3515
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.9316 - loss: 0.3517 - val_accuracy: 0.9717 - val_loss: 0.2463 - learning_rate: 6.2500e-05
# Epoch 47/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9267 - loss: 0.3598 - val_accuracy: 0.9725 - val_loss: 0.2452 - learning_rate: 3.1250e-05
# Epoch 48/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9283 - loss: 0.3667 - val_accuracy: 0.9732 - val_loss: 0.2450 - learning_rate: 3.1250e-05
# Epoch 49/50
# 299/303 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9265 - loss: 0.3561
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - accuracy: 0.9265 - loss: 0.3561 - val_accuracy: 0.9732 - val_loss: 0.2471 - learning_rate: 3.1250e-05
# Epoch 50/50
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9298 - loss: 0.3473 - val_accuracy: 0.9732 - val_loss: 0.2447 - learning_rate: 1.5625e-05

# %%
# Plot two plots of accuracy and loss for both train and validation
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 4))

# Plot train and validation accuracy
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title('Model Accuracy')
ax1.set_ylabel('Accuracy')
ax1.set_xlabel('Epoch')
ax1.legend(['Train', 'Validation'])

# Plot train and validation accuracy loss
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title('Model Loss')
ax2.set_ylabel('Loss')
ax2.set_xlabel('Epoch')
ax2.legend(['Train', 'Validation'])

plt.show()

# %%
import matplotlib.pyplot as plt

# History'den verileri alalım
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# En iyi doğruluk ve en düşük kayıp değerlerini tespit edelim
best_train_acc = max(accuracy)
best_train_epoch_acc = accuracy.index(best_train_acc) + 1  # En iyi epok
best_val_acc = max(val_accuracy)
best_val_epoch_acc = val_accuracy.index(best_val_acc) + 1

lowest_train_loss = min(loss)
lowest_train_epoch_loss = loss.index(lowest_train_loss) + 1
lowest_val_loss = min(val_loss)
lowest_val_epoch_loss = val_loss.index(lowest_val_loss) + 1

# Sütun grafiği için veriler
categories_accuracy = ['Eğitim Doğruluk', 'Doğrulama Doğruluk']
values_accuracy = [best_train_acc, best_val_acc]

categories_loss = ['Eğitim Kayıp', 'Doğrulama Kayıp']
values_loss = [lowest_train_loss, lowest_val_loss]

# Accuracy Sütun Grafiği
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.bar(categories_accuracy, values_accuracy, color=['blue', 'orange'])
plt.ylim(0, 1)  # Doğruluklar 0 ile 1 arasında
plt.title('En İyi Doğruluk (Accuracy)')
plt.ylabel('Doğruluk (Accuracy)')
plt.text(0, best_train_acc - 0.05, f'Epok: {best_train_epoch_acc}\nAcc: {best_train_acc:.2f}', ha='center', color='white', fontsize=10)
plt.text(1, best_val_acc - 0.05, f'Epok: {best_val_epoch_acc}\nAcc: {best_val_acc:.2f}', ha='center', color='white', fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Loss Sütun Grafiği
plt.subplot(1, 2, 2)
plt.bar(categories_loss, values_loss, color=['green', 'red'])
plt.title('En Düşük Kayıp (Loss)')
plt.ylabel('Kayıp (Loss)')
plt.text(0, lowest_train_loss + 0.01, f'Epok: {lowest_train_epoch_loss}\nLoss: {lowest_train_loss:.4f}', ha='center', color='white', fontsize=10)
plt.text(1, lowest_val_loss + 0.01, f'Epok: {lowest_val_epoch_loss}\nLoss: {lowest_val_loss:.4f}', ha='center', color='white', fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# Test model performance using test data
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print('The model accuracy is ' + f"{test_accuracy*100:.1f}" + '%')
# Out:
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9726 - loss: 0.2376
# The model accuracy is 97.6%

# %%
model.summary()
model.save("Arabic_handwriiten_CNN_Model.keras")
from google.colab import drive

# Google Drive
drive.mount('/content/drive')
model.save('/content/drive/MyDrive/Arabic_handwriiten_CNN_Model.keras')
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_11 (InputLayer)          │ (None, 32, 32, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_54 (Conv2D)                   │ (None, 32, 32, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_26               │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_55 (Conv2D)                   │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_4                  │ (None, 16, 16, 32)          │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_26 (Dropout)                 │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_56 (Conv2D)                   │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_27               │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_57 (Conv2D)                   │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_5                  │ (None, 8, 8, 64)            │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_27 (Dropout)                 │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_58 (Conv2D)                   │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_28               │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_59 (Conv2D)                   │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_6                  │ (None, 4, 4, 128)           │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_28 (Dropout)                 │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_4           │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_29 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 28)                  │           7,196 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 981,750 (3.75 MB)
#  Trainable params: 327,100 (1.25 MB)
#  Non-trainable params: 448 (1.75 KB)
#  Optimizer params: 654,202 (2.50 MB)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
num_to_arabic = {
    1: "ا",
    2: "ب",
    3: "ت",
    4: "ث",
    5: "ج",
    6: "ح",
    7: "خ",
    8: "د",
    9: "ذ",
    10: "ر",
    11: "ز",
    12: "س",
    13: "ش",
    14: "ص",
    15: "ض",
    16: "ط",
    17: "ظ",
    18: "ع",
    19: "غ",
    20: "ف",
    21: "ق",
    22: "ك",
    23: "ل",
    24: "م",
    25: "ن",
    26: "ه",
    27: "و",
    28: "ي"
}

# %%
# Numara etiketlerini harfe dönüştürme
def convert_labels_to_arabic(labels, mapping):
    return [mapping.get(label + 1, '') for label in labels] # Use get with default value to handle missing keys
# Örnek kullanım
num_labels = [1, 2, 3, 10, 28]  # Örnek olarak verilen numara etiketleri
arabic_labels = convert_labels_to_arabic(num_labels, num_to_arabic)
print("Arabic Labels:", arabic_labels)
# Çıktı: ['ا', 'ب', 'ت', 'ر', 'ي']
# Out:
# Arabic Labels: ['ب', 'ت', 'ث', 'ز', '']

# %%
# Prediction Function

def predict_random_samples(model, x_test, y_test, num_samples=5):
    """
    Predicts random samples from the test set and displays the images alongside the predictions.
    """
    indices = random.sample(range(len(x_test)), num_samples)
    selected_images = x_test[indices]
    true_labels = np.argmax(y_test[indices], axis=1)
    predictions = model.predict(selected_images)
    predicted_labels = np.argmax(predictions, axis=1)

    # Plot the selected samples with true and predicted labels
    plt.figure(figsize=(15, 5))
    for i, image in enumerate(selected_images):
        plt.subplot(1, num_samples, i + 1)
        plt.imshow(image.squeeze(), cmap='gray')
        plt.title(f"True: {true_labels[i]}\nPred: {predicted_labels[i]}")
        plt.axis('off')
    plt.show()

# Confusion Matrix Function
def plot_confusion_matrix(y_true, y_pred):
    """
    Plots a confusion matrix for the true vs predicted labels.
    """
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sn.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(1, 29), yticklabels=range(1, 29))
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# Grid Visualization Function
def show_img_grid(images, labels, N, mapping):
    fig, axes = plt.subplots(1, N, figsize=(15, 5))
    arabic_labels = convert_labels_to_arabic(labels, mapping)
    for i in range(N):
        axes[i].imshow(images[i], cmap='gray')
        axes[i].set_title(f"Prediction: {arabic_labels[i]}")
        axes[i].axis('off')
    plt.tight_layout()
    plt.show()


# Predictions and Confusion Matrix
predicted_probs = model.predict(x_test)
y_pred = np.argmax(predicted_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

# Call Functions
predict_random_samples(model, x_test, y_test, num_samples=5)
plot_confusion_matrix(y_true, y_pred)

# Example for Grid Visualization
N = 9  # Number of images to display
grid_images = []
grid_labels = []

for i in range(N):
    idx = random.randint(0, len(x_test) - 1)
    grid_images.append(x_test[idx].squeeze())
    grid_labels.append(y_pred[idx])

show_img_grid(grid_images, grid_labels, N, num_to_arabic)
# Out:
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step

# %%
# Classification Report
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=[str(i) for i in range(1, 29)]))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99       120
#            2       0.99      0.99      0.99       120
#            3       0.93      0.97      0.95       120
#            4       0.98      0.97      0.97       120
#            5       0.98      1.00      0.99       120
#            6       0.97      0.97      0.97       120
#            7       0.99      0.98      0.99       120
#            8       0.98      0.93      0.96       120
#            9       0.96      0.93      0.95       120
#           10       0.94      0.98      0.96       120
#           11       0.95      0.93      0.94       120
#           12       0.98      1.00      0.99       120
#           13       0.99      0.99      0.99       120
#           14       0.98      0.99      0.98       120
#           15       0.99      0.97      0.98       120
#           16       0.96      0.99      0.98       120
#           17       1.00      0.96      0.98       120
#           18       0.97      0.97      0.97       120
#           19       0.98      1.00      0.99       120
#           20       0.98      0.97      0.98       120
#           21       0.97      0.97      0.97       120
#           22       0.98      0.98      0.98       120
#           23       0.97      0.98      0.98       120
#           24       0.98      0.97      0.98       120
#           25       0.97      0.96      0.97       120
#           26       0.98      0.98      0.98       120
#           27       0.98      0.98      0.98       120
#           28       0.99      1.00      1.00       120
#
#     accuracy                           0.98      3360
#    macro avg       0.98      0.98      0.98      3360
# weighted avg       0.98      0.98      0.98      3360
